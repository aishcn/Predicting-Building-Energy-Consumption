# %% [markdown]
# ## 2. Feature Selection & Transformations
#
# - 2.1. Feature Importance Using Random Forest
# - 2.2. Feature Engineering
# - 2.3. Feature Transformations
# - 2.4. Further Correlation Analysis
# - 2.5. Feature Selection Using `boruta` package
# - 2.6. Principal Componenet Analysis (PCA)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
#import tensorflow as tf
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression
from matplotlib.ticker import StrMethodFormatter
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.pipeline import Pipeline
from sklearn.model_selection import KFold
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import OrdinalEncoder
from sklearn import model_selection
import re
from boruta import BorutaPy
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
import pickle
from mpl_toolkits.mplot3d import Axes3D
from bioinfokit.visuz import cluster
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data/1_eda.csv')
#test = pd.read_csv('data/1_test.csv')

# %% [markdown]
# ### 2.1. Feature Importance Using Random Forest

# %%
rf = RandomForestRegressor(n_estimators=80, max_features='auto')
rf.fit(df.iloc[:,:-1], df['site_eui'])
print("Training done using Random Forest")

rank = np.argsort(-rf.feature_importances_)
f, ax = plt.subplots(figsize=(11,9))
sns.barplot(x=rf.feature_importances_[rank], y=df.iloc[:,:-1].columns.values[rank], orient='h')
ax.set_xlabel("Feature Importance")
plt.tight_layout()
plt.show()
# Out:
# Training done using Random Forest

# %% [markdown]
# ### 2.2. Feature Engineering

# %%
# Interaction Terms
df['floorxBuilt'] = df.floor_area * df.year_built 
df['floorxEnergy'] = df.floor_area * df.energy_star_rating
df['floorxBuiltxEnergy'] = df.floor_area * df.year_built * df.energy_star_rating
df['floorxHeatCool'] = df.floor_area *(df.cooling_degree_days + df.heating_degree_days)
df["floorxELEVATION"] = df.floor_area*df.ELEVATION

# Feature Engineering
df['SpringTemp'] = (df.march_avg_temp + df.april_avg_temp + df.may_avg_temp)/3
df['SummerTemp'] = (df.june_avg_temp + df.july_avg_temp + df.august_avg_temp)/3
df['FallTemp'] = (df.september_avg_temp + df.october_avg_temp + df.november_avg_temp)/3
df['WinterTemp'] = (df.december_avg_temp + df.january_avg_temp + df.february_avg_temp)/3
df["freezing_days"] = df.days_below_0F + df.days_below_10F
df["cold_days"] = df.days_below_20F + df.days_below_30F
df["warm_days"] = df.days_above_80F + df.days_above_90F
df["hot_days"] = df.days_above_100F + df.days_above_110F
df["snow_rain_inches"] = df.snowfall_inches + df.precipitation_inches

# %%
## Removing temperature related redundant features used above
## Building Characteristic features to be investigated further 
df = df.drop(['days_below_30F', 'days_below_20F', 'days_below_10F',
       'days_below_0F', 'days_above_80F', 'days_above_90F', 'days_above_100F',
       'days_above_110F','precipitation_inches', 'snowfall_inches', 'snowdepth_inches', 'january_avg_temp', 
         'january_max_temp', 'february_min_temp',
       'february_avg_temp', 'february_max_temp', 'march_min_temp',
       'march_avg_temp', 'march_max_temp', 'april_min_temp', 'april_avg_temp',
       'april_max_temp', 'may_min_temp', 'may_avg_temp', 'may_max_temp',
       'june_min_temp', 'june_avg_temp', 'june_max_temp', 'july_min_temp',
       'july_avg_temp', 'july_max_temp', 'august_min_temp', 'august_avg_temp',
       'august_max_temp', 'september_min_temp', 'september_avg_temp',
       'september_max_temp', 'october_min_temp', 'october_avg_temp',
       'october_max_temp', 'november_min_temp', 'november_avg_temp',
       'november_max_temp', 'december_min_temp', 'december_avg_temp',
       'december_max_temp', 'cooling_degree_days', 'heating_degree_days'],1)

# %%
## No skewness therefore no need for transformations on the response variable
ax = sns.distplot(df['site_eui'])
plt.show()

# %%
df.columns
# Out:
# Index(['Year_Factor', 'building_class', 'facility_type', 'floor_area',
#        'year_built', 'energy_star_rating', 'ELEVATION', 'avg_temp', 'site_eui',
#        'floorxBuilt', 'floorxEnergy', 'floorxBuiltxEnergy', 'floorxHeatCool',
#        'floorxELEVATION', 'SpringTemp', 'SummerTemp', 'FallTemp', 'WinterTemp',
#        'freezing_days', 'cold_days', 'warm_days', 'hot_days',
#        'snow_rain_inches'],
#       dtype='object')

# %%
df_t = df.copy()

# %% [markdown]
# ### 2.3.Feature Transformations
# Looking at individual columns in order to investigate the feature distributions and skewness (if present) in depth

# %%
sns.distplot(df_t.drop('site_eui',1).floor_area)

# %%
## Distribution right skewed therefore Inverse Power/Root Transform performed
df_t.floor_area = (df_t.floor_area)**(1/6)
sns.distplot(df_t.floor_area)

# %%
sns.distplot(df_t.year_built)

# %%
## Distribution left skewed therefore a log transform is performed
## 2020 (roughly max value) subtracted from the year_built inside the log transform to center the distribution
df_t.year_built = np.log(2020-df_t.year_built)
sns.distplot(df_t.year_built)

# %%
sns.distplot(df_t.energy_star_rating)

# %%
## Distribution left skewed therefore Square Transform performed to center the distribution
df_t.energy_star_rating = (df_t.energy_star_rating)**2
sns.distplot(df_t.energy_star_rating)

# %%
sns.distplot(df_t.ELEVATION)

# %%
## Distribution right skewed therefore Inverse Power/Root Transform performed
df_t.ELEVATION = (df_t.ELEVATION)**(1/6)
sns.distplot(df_t.ELEVATION)

# %%
sns.distplot(df_t.avg_temp)

# %%
sns.distplot(df_t.SpringTemp)

# %%
sns.distplot(df_t.SummerTemp)

# %%
sns.distplot(df_t.FallTemp)

# %%
sns.distplot(df_t.WinterTemp)

# %%
sns.distplot(df_t.floorxBuilt)

# %%
## Noisy Distribution therefore Inverse Power/Root Transform performed to achieve the desired result
df_t.floorxBuilt = (df_t.floorxBuilt)**(1/6)
sns.distplot(df_t.floorxBuilt)

# %%
sns.distplot(df_t.floorxEnergy)

# %%
## Distribution left skewed therefore Inverse Power/Root Transform performed
df_t.floorxEnergy = (df_t.floorxEnergy)**(1/6)
sns.distplot(df_t.floorxEnergy)

# %%
sns.distplot(df_t.floorxBuiltxEnergy)

# %%
## Non-normal Distribution therefore Inverse Power/Root Transform performed to achieve the desired result
df_t.floorxBuiltxEnergy = (df_t.floorxBuiltxEnergy)**(1/6)
sns.distplot(df_t.floorxBuiltxEnergy)

# %%
sns.distplot(df_t.floorxHeatCool)

# %%
## Non-normal distribution therefore Inverse Power/Root Transform performed
df_t.floorxHeatCool = df_t.floorxHeatCool**(1/6)
sns.distplot(df_t.floorxHeatCool)

# %%
sns.distplot(df_t.freezing_days)

# %%
## Distribution right skewed therefore Inverse Power/Root Transform performed
df_t.freezing_days = (df_t.freezing_days)**(1/5)
sns.distplot(df_t.freezing_days)

# %%
sns.distplot(df_t.cold_days)

# %%
## Distribution slightly right skewed therefore Square Root Transform performed
df_t.cold_days = df_t.cold_days**(1/2)
sns.distplot(df_t.cold_days)

# %%
sns.distplot(df_t.warm_days)

# %%
## Distribution slightly right skewed therefore Square Root Transform performed
df_t.warm_days = df_t.warm_days**(1/2)
sns.distplot(df_t.warm_days)

# %%
sns.distplot(df_t.hot_days)

# %%
## Majority of the values present in column hot_days are 0, therefore dropping the column
df_t = df_t.drop('hot_days',1)

# %%
sns.distplot(df_t.floorxEnergy)

# %%
## Distribution right skewed therefore Inverse Power/Root Transform performed
df_t.floorxEnergy = df_t.floorxEnergy**(1/6)
sns.distplot(df_t.floorxEnergy)

# %%
sns.distplot(df_t.floorxELEVATION)

# %%
## Distribution right skewed therefore Inverse Power/Root Transform performed
df_t.floorxELEVATION = df_t.floorxELEVATION**(1/8)
sns.distplot(df_t.floorxELEVATION)

# %%
## Performing median imputations on NA values created due to the above log transformations
df_t = df_t.fillna(df_t.median())

# %% [markdown]
# ### 2.4. Further Correlation Analysis

# %%
## Checking the correlations again after feature engineering
plt.figure(figsize=(16, 6))
mask = np.triu(np.ones_like(df_t.drop('site_eui',1).corr(method = 'spearman'), dtype=np.bool))
heatmap = sns.heatmap(df_t.drop('site_eui',1).corr(), mask=mask, vmin=-1, vmax=1, annot=False, cmap='BrBG')
heatmap.set_title('Triangle Correlation Heatmap', fontdict={'fontsize':10}, pad=16);

# %%
## Dropping some highly correlated features from the matrix above
df_t = df_t.drop(['floorxBuilt','floorxBuiltxEnergy','floorxHeatCool','floorxEnergy', 'floorxELEVATION','SpringTemp',
                 'WinterTemp'],1)

# %%
## Extracting highly correlated features from the correlation matrix with the specified threshold i.e.
## absolute value of the correlation coefficient 

#' @param df1: dataframe 
#' @param threshold: absolute value of correlation coefficient
#' @return a set with pairs of highly correlated features based on the threshold set above

def pairwise_correlation(df1, threshold):
    highly_correlated = set()
    corr_mat = df1.corr(method = 'spearman')
    for i in range(len(corr_mat.columns)):
        for j in range(i):
            if (np.abs(corr_mat.iloc[i, j]) >= threshold) and ((corr_mat.columns[j], corr_mat.columns[i]) not in highly_correlated):
                col = (corr_mat.columns[i], corr_mat.columns[j])
                highly_correlated.add(col)

    return highly_correlated

highly_correlated = pairwise_correlation(df_t, 0.75)
highly_correlated
# Out:
# {('cold_days', 'freezing_days')}

# %% [markdown]
# ### 2.5. Feature Selection Using `boruta` package

# %%
## Performing Feature Selection using Boruta package after Feature Engineering
## Boruta: https://pypi.org/project/Boruta/

forest = RandomForestRegressor(max_depth = 5)
forest.fit(df_t.drop('site_eui',1).values, df_t['site_eui'].values)

## define Boruta feature selection method
feat_selector = BorutaPy(forest, n_estimators='auto', verbose=2, random_state=1)

## find all relevant features
feat_selector.fit(df_t.drop('site_eui',1).values, df_t['site_eui'].values)

## check selected features
feat_selector.support_
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	14
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	14
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	14
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	14
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	14
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	14
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	14
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	10
# Tentative: 	4
# Rejected: 	0
# Iteration: 	9 / 100
# Confirmed: 	10
# Tentative: 	4
# Rejected: 	0
# Iteration: 	10 / 100
# Confirmed: 	10
# Tentative: 	4
# Rejected: 	0
# Iteration: 	11 / 100
# Confirmed: 	10
# Tentative: 	4
# Rejected: 	0
# Iteration: 	12 / 100
# Confirmed: 	10
# Tentative: 	3
# Rejected: 	1
# Iteration: 	13 / 100
# Confirmed: 	10
# Tentative: 	3
# Rejected: 	1
# Iteration: 	14 / 100
# Confirmed: 	10
# Tentative: 	3
# Rejected: 	1
# Iteration: 	15 / 100
# Confirmed: 	10
# Tentative: 	3
# Rejected: 	1
# Iteration: 	16 / 100
# Confirmed: 	10
# Tentative: 	3
# Rejected: 	1
# Iteration: 	17 / 100
# Confirmed: 	10
# Tentative: 	3
# Rejected: 	1
# Iteration: 	18 / 100
# Confirmed: 	10
# Tentative: 	3
# Rejected: 	1
# Iteration: 	19 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	20 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	21 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	22 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	23 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	24 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	25 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	26 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	27 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	28 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	29 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	30 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	31 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	32 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	33 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	34 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	35 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	36 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	37 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	38 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	39 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	40 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	41 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	42 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	43 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	44 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	45 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	46 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	47 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	48 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	49 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	50 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	2
# Iteration: 	51 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	52 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	53 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	54 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	55 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	56 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	57 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	58 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	59 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	60 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	61 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	62 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	63 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	64 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	65 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	66 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	67 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	68 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	69 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	70 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	71 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	72 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	73 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	74 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	75 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	76 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	77 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	78 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	79 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	80 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	81 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	82 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	83 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	84 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	85 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	86 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3
# Iteration: 	87 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	3

# %%
## checking the ranking of features
feat_selector.ranking_

# %%
## selecting all the important features from the above method
selected = df_t.drop('site_eui',1).columns[np.array(feat_selector.support_)]
selected

# %%
feature_ranks = list(zip(df_t.drop('site_eui',1).columns, 
                         feat_selector.ranking_, 
                         feat_selector.support_))

for feat in feature_ranks:
    print('Feature: {:<25} Rank: {},  Keep: {}'.format(feat[0], feat[1], feat[2]))

# %%
## Checking what features correlate with Site EUI and how much
plt.figure(figsize=(8, 20))
heatmap = sns.heatmap(df_t.corr(method = 'spearman')[['site_eui']].sort_values(by='site_eui', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with Site EUI', fontdict={'fontsize':5}, pad=10);

# %%
## selecting all the important features from the above method
df_selected = df_t.drop('site_eui',1).loc[:,selected]

# %% [markdown]
# ### 2.6. Principal Componenet Analysis (PCA)

# %%
## Performed Min Max Scaling because PCA is solved via SVD and SVD approximates in the sum of squares sense
## so if one variable is on a different scale than another, it will dominate the PCA procedure.

scaler = MinMaxScaler()
data_rescaled = scaler.fit_transform(df_selected)

## Aim to achieve 95% variance from PCA
pca = PCA(n_components = 0.95)
pca.fit(data_rescaled)
reduced = pca.transform(data_rescaled)

# %%
plt.rcParams["figure.figsize"] = (12,6)

fig, ax = plt.subplots()
xi = np.arange(1, 7, step=1)
y = np.cumsum(pca.explained_variance_ratio_)

plt.ylim(0.0,1.1)
plt.plot(xi, y, marker='o', linestyle='--', color='b')

plt.xlabel('Number of Components')
plt.xticks(np.arange(0, 11, step=1))
plt.ylabel('Cumulative variance (%)')
plt.title('The number of components needed to explain variance')

plt.axhline(y=0.95, color='r', linestyle='-')
plt.text(0.5, 0.85, '95% cut-off threshold', color = 'red', fontsize=16)

ax.grid(axis='x')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(reduced[:,0],reduced[:,1], c=df_t['site_eui'])
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')

print(pca.explained_variance_ratio_)
plt.figure(figsize=(8,6))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
# Out:
# [0.44208036 0.23665123 0.14955687 0.07433279 0.02787862 0.02355317]
# Text(0, 0.5, 'Cumulative explained variance')

# %%
# 4-D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = reduced[:,0]
y = reduced[:,1]
z = reduced[:,2]
c = reduced[:,3]
c = reduced[:,4]

img = ax.scatter(x, y, z, c=c, cmap=plt.cool())
fig.colorbar(img)
plt.show()

# %%
reduced_df = pd.DataFrame(reduced, columns = ['PC1', 'PC2','PC3','PC4','PC5','PC6'])
reduced_df.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6
# 0  0.657747 -0.583257 -0.330265 -0.205520 -0.198617 -0.077649
# 1  0.773327 -0.587428  0.398278 -0.212447 -0.172514 -0.084981
# 2  0.565900 -0.611901 -0.304283  0.458800 -0.230882 -0.106130
# 3  0.779904 -0.598242  0.452290 -0.205367 -0.207722 -0.150883
# 4  0.727304 -0.592578  0.116474 -0.205116 -0.213476 -0.066243

# %%
reduced_df.to_csv('data/2_fs.csv', index = False)
df_t.to_csv('data/2_df_transform.csv', index = False)
